# %%
#!pip install Jinja2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor


from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv("../../data/preprocessed/warm_wasser_weather.csv",delimiter=',',encoding='UTF-8')

# %%
def timestamp_to_datetime(timestamp):
    return datetime.datetime.fromisoformat(timestamp)

# %%
df['timestamp'] = df['timestamp'].apply(timestamp_to_datetime)

# %%
df['day'] = [x.day for x in df['timestamp']]
df['month'] = [x.month for x in df['timestamp']]
df['year'] = [x.year for x in df['timestamp']]
df['hour'] = [x.hour for x in df['timestamp']]
#minute not imp if we're sampling hourly
#df['minute'] = [x.minute for x in df['timestamp']]

# %% [markdown]
# ### Considering only electricity usage as energy type

# %%
df = df[['timestamp', 'warm_wasser','Graz Temperature [2 m elevation corrected]',
       'Graz Shortwave Radiation', 'Graz Direct Shortwave Radiation',
       'Graz Diffuse Shortwave Radiation', 'Graz Relative Humidity [2 m]',
       'is_schoolday', 'day', 'month', 'year', 'hour']]

# %%
df
# Out:
#                 timestamp  warm_wasser  \
# 0     2021-06-14 00:15:00          0.0
# 1     2021-06-14 00:30:00          0.0
# 2     2021-06-14 00:45:00          0.0
# 3     2021-06-14 01:00:00          2.0
# 4     2021-06-14 01:15:00          3.0
# ...                   ...          ...
# 39600 2022-07-31 12:15:00          0.0
# 39601 2022-07-31 12:30:00          0.0
# 39602 2022-07-31 12:45:00          0.0
# 39603 2022-07-31 13:00:00          0.0
# 39604 2022-07-31 13:15:00          0.0
#
#        Graz Temperature [2 m elevation corrected]  Graz Shortwave Radiation  \
# 0                                         4.32137                    0.0000
# 1                                         4.30637                    0.0000
# 2                                         4.29137                    0.0000
# 3                                         4.27637                    0.0000
# 4                                         4.26137                    0.0000
# ...                                           ...                       ...
# 39600                                     9.17137                  461.9100
# 39601                                     9.68387                  476.8175
# 39602                                    10.19637                  491.7250
# 39603                                    10.70887                  506.6325
# 39604                                    11.22137                  521.5400
#
#        Graz Direct Shortwave Radiation  Graz Diffuse Shortwave Radiation  \
# 0                             0.000000                          0.000000
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.000000                          0.000000
# ...                                ...                               ...
# 39600                       275.060550                        186.849460
# 39601                       285.217105                        191.600403
# 39602                       295.373660                        196.351345
# 39603                       305.530215                        201.102287
# 39604                       315.686770                        205.853230
#
#        Graz Relative Humidity [2 m]  is_schoolday  day  month  year  hour
# 0                              73.0             1   14      6  2021     0
# 1                              71.0             1   14      6  2021     0
# 2                              69.0             1   14      6  2021     0
# 3                              67.0             1   14      6  2021     1
# 4                              65.0             1   14      6  2021     1
# ...                             ...           ...  ...    ...   ...   ...
# 39600                          42.0             0   31      7  2022    12
# 39601                          41.5             0   31      7  2022    12
# 39602                          41.0             0   31      7  2022    12
# 39603                          40.5             0   31      7  2022    13
# 39604                          40.0             0   31      7  2022    13
#
# [39605 rows x 12 columns]

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_15276/543879950.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient(cmap='coolwarm')
# <style type="text/css">
# #T_f58cc_row0_col0, #T_f58cc_row1_col1, #T_f58cc_row2_col2, #T_f58cc_row3_col3, #T_f58cc_row4_col4, #T_f58cc_row5_col5, #T_f58cc_row6_col6, #T_f58cc_row7_col7, #T_f58cc_row8_col8, #T_f58cc_row9_col9, #T_f58cc_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f58cc_row0_col1, #T_f58cc_row1_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_f58cc_row0_col2, #T_f58cc_row2_col9, #T_f58cc_row4_col9 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f58cc_row0_col3, #T_f58cc_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_f58cc_row0_col4, #T_f58cc_row2_col10, #T_f58cc_row6_col4, #T_f58cc_row6_col8, #T_f58cc_row7_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f58cc_row0_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f58cc_row0_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f58cc_row0_col7, #T_f58cc_row2_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f58cc_row0_col8, #T_f58cc_row1_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_f58cc_row0_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_f58cc_row0_col10 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f58cc_row1_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f58cc_row1_col2 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_f58cc_row1_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_f58cc_row1_col4 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_f58cc_row1_col5, #T_f58cc_row5_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f58cc_row1_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_f58cc_row1_col8, #T_f58cc_row7_col9, #T_f58cc_row8_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f58cc_row1_col10 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_f58cc_row2_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f58cc_row2_col1, #T_f58cc_row4_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_f58cc_row2_col3, #T_f58cc_row3_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_f58cc_row2_col4, #T_f58cc_row4_col2 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_f58cc_row2_col5, #T_f58cc_row5_col0, #T_f58cc_row5_col1, #T_f58cc_row5_col2, #T_f58cc_row5_col3, #T_f58cc_row5_col4, #T_f58cc_row5_col10, #T_f58cc_row6_col7, #T_f58cc_row8_col6, #T_f58cc_row8_col9, #T_f58cc_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f58cc_row2_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f58cc_row2_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f58cc_row3_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f58cc_row3_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_f58cc_row3_col4, #T_f58cc_row4_col3 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_f58cc_row3_col5, #T_f58cc_row10_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f58cc_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f58cc_row3_col7, #T_f58cc_row10_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f58cc_row3_col8, #T_f58cc_row10_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f58cc_row3_col9, #T_f58cc_row4_col10 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f58cc_row3_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f58cc_row4_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f58cc_row4_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_f58cc_row4_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f58cc_row4_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f58cc_row4_col8 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f58cc_row5_col6, #T_f58cc_row9_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f58cc_row5_col8 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_f58cc_row5_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_f58cc_row6_col0, #T_f58cc_row7_col6 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f58cc_row6_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_f58cc_row6_col3, #T_f58cc_row8_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f58cc_row6_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_f58cc_row6_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_f58cc_row6_col10, #T_f58cc_row7_col10, #T_f58cc_row8_col10, #T_f58cc_row9_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f58cc_row7_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f58cc_row7_col1, #T_f58cc_row9_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f58cc_row7_col2, #T_f58cc_row7_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_f58cc_row7_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f58cc_row7_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f58cc_row8_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f58cc_row8_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_f58cc_row8_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_f58cc_row8_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f58cc_row8_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f58cc_row9_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f58cc_row9_col2, #T_f58cc_row9_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_f58cc_row9_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_f58cc_row9_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f58cc_row9_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f58cc_row10_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_f58cc_row10_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f58cc_row10_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f58cc_row10_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f58cc_row10_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f58cc_row10_col8, #T_f58cc_row10_col9 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# </style>
# <table id="T_f58cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f58cc_level0_col0" class="col_heading level0 col0" >warm_wasser</th>
#       <th id="T_f58cc_level0_col1" class="col_heading level0 col1" >Graz Temperature [2 m elevation corrected]</th>
#       <th id="T_f58cc_level0_col2" class="col_heading level0 col2" >Graz Shortwave Radiation</th>
#       <th id="T_f58cc_level0_col3" class="col_heading level0 col3" >Graz Direct Shortwave Radiation</th>
#       <th id="T_f58cc_level0_col4" class="col_heading level0 col4" >Graz Diffuse Shortwave Radiation</th>
#       <th id="T_f58cc_level0_col5" class="col_heading level0 col5" >Graz Relative Humidity [2 m]</th>
#       <th id="T_f58cc_level0_col6" class="col_heading level0 col6" >is_schoolday</th>
#       <th id="T_f58cc_level0_col7" class="col_heading level0 col7" >day</th>
#       <th id="T_f58cc_level0_col8" class="col_heading level0 col8" >month</th>
#       <th id="T_f58cc_level0_col9" class="col_heading level0 col9" >year</th>
#       <th id="T_f58cc_level0_col10" class="col_heading level0 col10" >hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f58cc_level0_row0" class="row_heading level0 row0" >warm_wasser</th>
#       <td id="T_f58cc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f58cc_row0_col1" class="data row0 col1" >0.007125</td>
#       <td id="T_f58cc_row0_col2" class="data row0 col2" >0.025270</td>
#       <td id="T_f58cc_row0_col3" class="data row0 col3" >0.022605</td>
#       <td id="T_f58cc_row0_col4" class="data row0 col4" >0.028077</td>
#       <td id="T_f58cc_row0_col5" class="data row0 col5" >-0.016234</td>
#       <td id="T_f58cc_row0_col6" class="data row0 col6" >0.035213</td>
#       <td id="T_f58cc_row0_col7" class="data row0 col7" >-0.003419</td>
#       <td id="T_f58cc_row0_col8" class="data row0 col8" >-0.008079</td>
#       <td id="T_f58cc_row0_col9" class="data row0 col9" >0.018620</td>
#       <td id="T_f58cc_row0_col10" class="data row0 col10" >-0.011939</td>
#     </tr>
#     <tr

# %%
X = df[['Graz Temperature [2 m elevation corrected]',
       'Graz Shortwave Radiation', 'Graz Direct Shortwave Radiation',
       'Graz Diffuse Shortwave Radiation', 'Graz Relative Humidity [2 m]',
       'is_schoolday', 'day', 'month', 'hour']]
Y = df['warm_wasser']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Fitting warm_wasser DTR model

# %% [markdown]
# ### Decision Tree Regressor

# %%
DecTreeReg= DecisionTreeRegressor()
DecTreeReg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
DTRPred=DecTreeReg.predict(X_test)

# %% [markdown]
# Evaluation

# %%
mse = (np.sqrt(mean_squared_error(y_test, DTRPred)))
r2= r2_score(y_test, DTRPred)
mae = mean_absolute_error(y_test, DTRPred)
print("Perfomance for test set {:.2f}".format(r2))
# Out:
# Perfomance for test set -0.32

# %%
plt.figure()
plt.figure(figsize=(7, 7))
plt.grid()
plt.scatter(y_test,DTRPred,alpha=0.5
        ,color='green',label=r'$R^2 = $ {:.2f}'.format(r2))
plt.title("Tree Regressor Model")
plt.ylabel("Real values")
plt.xlabel("Predicted values")
plt.legend(prop={'size': 15})
plt.show()

# %%
df.describe().T
# Out:
#                                               count         mean         std  \
# warm_wasser                                 39605.0     0.442772    0.757709
# Graz Temperature [2 m elevation corrected]  39605.0    11.738588    9.062119
# Graz Shortwave Radiation                    39605.0   157.898718  221.420788
# Graz Direct Shortwave Radiation             39605.0    93.897102  144.173639
# Graz Diffuse Shortwave Radiation            39605.0    64.001615   83.208253
# Graz Relative Humidity [2 m]                39605.0    63.809077   14.705589
# is_schoolday                                39605.0     0.513849    0.499814
# day                                         39605.0    15.984143    8.761931
# month                                       39605.0     6.539477    3.247397
# year                                        39605.0  2021.512814    0.499842
# hour                                        39605.0    11.493145    6.921602
#
#                                                    min         25%  \
# warm_wasser                                    0.00000     0.00000
# Graz Temperature [2 m elevation corrected]    -8.69863     3.52137
# Graz Shortwave Radiation                       0.00000     0.00000
# Graz Direct Shortwave Radiation               -6.14830     0.00000
# Graz Diffuse Shortwave Radiation               0.00000     0.00000
# Graz Relative Humidity [2 m]                  24.00000    53.00000
# is_schoolday                                   0.00000     0.00000
# day                                            1.00000     8.00000
# month                                          1.00000     4.00000
# year                                        2021.00000  2021.00000
# hour                                           0.00000     5.00000
#
#                                                     50%          75%  \
# warm_wasser                                    0.000000     1.000000
# Graz Temperature [2 m elevation corrected]    11.821370    19.391370
# Graz Shortwave Radiation                      13.795000   279.460000
# Graz Direct Shortwave Radiation                3.675384   156.358585
# Graz Diffuse Shortwave Radiation               6.621481   126.277370
# Graz Relative Humidity [2 m]                  63.000000    74.000000
# is_schoolday                                   1.000000     1.000000
# day                                           16.000000    24.000000
# month                                          7.000000     9.000000
# year                                        2022.000000  2022.000000
# hour                                          11.000000    17.000000
#
#                                                     max
# warm_wasser                                    8.000000
# Graz Temperature [2 m elevation corrected]    32.621372
# Graz Shortwave Radiation                     901.570000
# Graz Direct Shortwave Radiation              612.543100
# Graz Diffuse Shortwave Radiation             301.075260
# Graz Relative Humidity [2 m]                  98.000000
# is_schoolday                                   1.000000
# day                                           31.000000
# month                                         12.000000
# year                                        2022.000000
# hour                                          23.000000

# %%
test_df = X_test
test_df['warm_wasser_pred'] = DTRPred
test_df['warm_wasser_real'] = y_test

# %%
test_df
# Out:
#        Graz Temperature [2 m elevation corrected]  Graz Shortwave Radiation  \
# 32128                                    4.471370                   194.020
# 21385                                   25.906370                   331.080
# 2992                                     4.031370                     0.000
# 18586                                   25.701370                   804.115
# 19111                                   19.656371                     0.000
# ...                                           ...                       ...
# 35625                                    0.268870                     0.000
# 33977                                    4.381370                     0.000
# 22571                                   22.251370                     0.000
# 2865                                     6.828870                     0.000
# 34740                                    5.651370                     0.000
#
#        Graz Direct Shortwave Radiation  Graz Diffuse Shortwave Radiation  \
# 32128                       106.979740                         87.040270
# 21385                       198.166172                        132.913837
# 2992                          0.000000                          0.000000
# 18586                       554.803085                        249.311900
# 19111                         0.000000                          0.000000
# ...                                ...                               ...
# 35625                         0.000000                          0.000000
# 33977                         0.000000                          0.000000
# 22571                         0.000000                          0.000000
# 2865                          0.000000                          0.000000
# 34740                         0.000000                          0.000000
#
#        Graz Relative Humidity [2 m]  is_schoolday  day  month  hour  \
# 32128                         55.00             0   14      5    16
# 21385                         46.50             0   22      1    18
# 2992                          68.00             0   15      7     4
# 18586                         40.50             0   24     12    14
# 19111                         57.00             0   30     12     2
# ...                             ...           ...  ...    ...   ...
# 35625                         55.00             1   20      6     2
# 33977                         70.25             1    2      6    22
# 22571                         52.75             1    4      2     3
# 2865                          67.00             0   13      7    20
# 34740                         47.00             1   10      6    21
#
#        warm_wasser_pred  warm_wasser_real
# 32128               2.0               2.0
# 21385               0.0               1.0
# 2992                1.0               0.0
# 18586               0.0               0.0
# 19111               2.0               1.0
# ...                 ...               ...
# 35625               0.0               1.0
# 33977               1.0               0.0
# 22571               2.0               0.0
# 2865                1.0               2.0
# 34740               0.0               0.0
#
# [7921 rows x 11 columns]
