# %%
#!pip install Jinja2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor


from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv("../../data/preprocessed/fbh_kalte_weather.csv",delimiter=',',encoding='UTF-8')

# %%
def timestamp_to_datetime(timestamp):
    date_str = timestamp.split(' ')[0]
    time_str = timestamp.split(' ')[1]
    datetime_obj = datetime.datetime(int(date_str.split('-')[0]), int(date_str.split('-')[1] ), int(date_str.split('-')[2]),int(time_str[:2]), int(time_str[3:4]))
    return datetime_obj

# %%
df['timestamp'] = df['timestamp'].apply(timestamp_to_datetime)

# %%
df['day'] = [x.day for x in df['timestamp']]
df['month'] = [x.month for x in df['timestamp']]
df['year'] = [x.year for x in df['timestamp']]
df['hour'] = [x.hour for x in df['timestamp']]
#minute not imp if we're sampling hourly
#df['minute'] = [x.minute for x in df['timestamp']]

# %% [markdown]
# ### Considering only electricity usage as energy type

# %%
df = df[['timestamp', 'fbh_kalte','Graz Temperature [2 m elevation corrected]',
       'Graz Shortwave Radiation', 'Graz Direct Shortwave Radiation',
       'Graz Diffuse Shortwave Radiation', 'Graz Relative Humidity [2 m]',
       'is_schoolday', 'day', 'month', 'year', 'hour']]

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_25583/543879950.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient(cmap='coolwarm')
# <style type="text/css">
# #T_547fb_row0_col0, #T_547fb_row1_col1, #T_547fb_row2_col2, #T_547fb_row3_col3, #T_547fb_row4_col4, #T_547fb_row5_col5, #T_547fb_row6_col6, #T_547fb_row7_col7, #T_547fb_row8_col8, #T_547fb_row9_col9, #T_547fb_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_547fb_row0_col1, #T_547fb_row10_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_547fb_row0_col2, #T_547fb_row0_col4, #T_547fb_row0_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_547fb_row0_col3, #T_547fb_row7_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_547fb_row0_col6, #T_547fb_row3_col8 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_547fb_row0_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_547fb_row0_col8, #T_547fb_row6_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_547fb_row0_col9, #T_547fb_row2_col9, #T_547fb_row3_col9, #T_547fb_row4_col9, #T_547fb_row6_col9 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_547fb_row0_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_547fb_row1_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_547fb_row1_col2, #T_547fb_row1_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_547fb_row1_col3, #T_547fb_row2_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_547fb_row1_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_547fb_row1_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_547fb_row1_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_547fb_row1_col8 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_547fb_row1_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_547fb_row1_col10 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_547fb_row2_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_547fb_row2_col3, #T_547fb_row3_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_547fb_row2_col4, #T_547fb_row4_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_547fb_row2_col5, #T_547fb_row5_col1, #T_547fb_row5_col2, #T_547fb_row5_col3, #T_547fb_row5_col4, #T_547fb_row5_col8, #T_547fb_row5_col10, #T_547fb_row7_col6, #T_547fb_row8_col7, #T_547fb_row8_col9, #T_547fb_row10_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_547fb_row2_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_547fb_row2_col7, #T_547fb_row3_col6, #T_547fb_row3_col7, #T_547fb_row4_col7, #T_547fb_row9_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_547fb_row2_col8 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_547fb_row2_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_547fb_row3_col0, #T_547fb_row10_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_547fb_row3_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_547fb_row3_col4, #T_547fb_row4_col3 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_547fb_row3_col5, #T_547fb_row5_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_547fb_row3_col10, #T_547fb_row7_col1, #T_547fb_row9_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_547fb_row4_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_547fb_row4_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_547fb_row4_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_547fb_row4_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_547fb_row4_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_547fb_row4_col10 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_547fb_row5_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_547fb_row5_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_547fb_row5_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_547fb_row6_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_547fb_row6_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_547fb_row6_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_547fb_row6_col3, #T_547fb_row9_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_547fb_row6_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_547fb_row6_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_547fb_row6_col7, #T_547fb_row7_col9, #T_547fb_row10_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_547fb_row6_col10, #T_547fb_row7_col10, #T_547fb_row8_col10 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_547fb_row7_col0, #T_547fb_row8_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_547fb_row7_col2, #T_547fb_row9_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_547fb_row7_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_547fb_row7_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_547fb_row7_col8, #T_547fb_row9_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_547fb_row8_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_547fb_row8_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_547fb_row8_col2, #T_547fb_row8_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_547fb_row8_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_547fb_row8_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_547fb_row9_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_547fb_row9_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_547fb_row9_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_547fb_row9_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_547fb_row9_col10 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_547fb_row10_col2, #T_547fb_row10_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_547fb_row10_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_547fb_row10_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_547fb_row10_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_547fb_row10_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# </style>
# <table id="T_547fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_547fb_level0_col0" class="col_heading level0 col0" >fbh_kalte</th>
#       <th id="T_547fb_level0_col1" class="col_heading level0 col1" >Graz Temperature [2 m elevation corrected]</th>
#       <th id="T_547fb_level0_col2" class="col_heading level0 col2" >Graz Shortwave Radiation</th>
#       <th id="T_547fb_level0_col3" class="col_heading level0 col3" >Graz Direct Shortwave Radiation</th>
#       <th id="T_547fb_level0_col4" class="col_heading level0 col4" >Graz Diffuse Shortwave Radiation</th>
#       <th id="T_547fb_level0_col5" class="col_heading level0 col5" >Graz Relative Humidity [2 m]</th>
#       <th id="T_547fb_level0_col6" class="col_heading level0 col6" >is_schoolday</th>
#       <th id="T_547fb_level0_col7" class="col_heading level0 col7" >day</th>
#       <th id="T_547fb_level0_col8" class="col_heading level0 col8" >month</th>
#       <th id="T_547fb_level0_col9" class="col_heading level0 col9" >year</th>
#       <th id="T_547fb_level0_col10" class="col_heading level0 col10" >hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_547fb_level0_row0" class="row_heading level0 row0" >fbh_kalte</th>
#       <td id="T_547fb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_547fb_row0_col1" class="data row0 col1" >0.159198</td>
#       <td id="T_547fb_row0_col2" class="data row0 col2" >0.003694</td>
#       <td id="T_547fb_row0_col3" class="data row0 col3" >-0.009830</td>
#       <td id="T_547fb_row0_col4" class="data row0 col4" >0.027403</td>
#       <td id="T_547fb_row0_col5" class="data row0 col5" >0.008853</td>
#       <td id="T_547fb_row0_col6" class="data row0 col6" >0.409645</td>
#       <td id="T_547fb_row0_col7" class="data row0 col7" >-0.066619</td>
#       <td id="T_547fb_row0_col8" class="data row0 col8" >0.192596</td>
#       <td id="T_547fb_row0_col9" class="data row0 col9" >-0.003540</td>
#       <td id="T_547fb_row0_col10" class="data row0 col10" >-0.253472</td>
#     </tr>
#     <tr>
#       <th id="T_547fb_level0_row1" class="row_heading level0 row1" >Graz Temperature [2 m elevation co

# %%
X = df[['Graz Temperature [2 m elevation corrected]',
       'Graz Shortwave Radiation', 'Graz Direct Shortwave Radiation',
       'Graz Diffuse Shortwave Radiation', 'Graz Relative Humidity [2 m]',
       'is_schoolday', 'day', 'month', 'hour']]
Y = df['fbh_kalte']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Fitting fbh_kalte DTR model

# %% [markdown]
# ### Decision Tree Regressor

# %%
DecTreeReg= DecisionTreeRegressor()
DecTreeReg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
DTRPred=DecTreeReg.predict(X_test)

# %% [markdown]
# Evaluation

# %%
mse = (np.sqrt(mean_squared_error(y_test, DTRPred)))
r2= r2_score(y_test, DTRPred)
mae = mean_absolute_error(y_test, DTRPred)
print("Perfomance for test set {:.2f}".format(r2))
# Out:
# Perfomance for test set 0.87

# %%
plt.figure()
plt.figure(figsize=(7, 7))
plt.grid()
plt.scatter(y_test,DTRPred,alpha=0.5
        ,color='green',label=r'$R^2 = $ {:.2f}'.format(r2))
plt.title("Tree Regressor Model")
plt.ylabel("Real values")
plt.xlabel("Predicted values")
plt.legend(prop={'size': 15})
plt.show()

# %%
df.describe().T
# Out:
#                                               count         mean         std  \
# fbh_kalte                                   19296.0     1.682925    1.490755
# Graz Temperature [2 m elevation corrected]  19296.0    11.829232    8.980778
# Graz Shortwave Radiation                    19296.0   183.010123  239.627666
# Graz Direct Shortwave Radiation             19296.0   109.140291  158.586891
# Graz Diffuse Shortwave Radiation            19296.0    73.869830   89.185585
# Graz Relative Humidity [2 m]                19296.0    64.895056   15.147880
# is_schoolday                                19296.0     0.437759    0.496124
# day                                         19296.0    16.357535    8.760894
# month                                       19296.0     9.198746    1.906615
# year                                        19296.0  2021.000052    0.007199
# hour                                        19296.0    11.500000    6.922366
#
#                                                    min         25%  \
# fbh_kalte                                      0.00000     0.74000
# Graz Temperature [2 m elevation corrected]    -8.69863     3.69137
# Graz Shortwave Radiation                       0.00000     0.00000
# Graz Direct Shortwave Radiation               -6.14830     0.00000
# Graz Diffuse Shortwave Radiation               0.00000     0.00000
# Graz Relative Humidity [2 m]                  28.00000    53.50000
# is_schoolday                                   0.00000     0.00000
# day                                            1.00000     9.00000
# month                                          1.00000     8.00000
# year                                        2021.00000  2021.00000
# hour                                           0.00000     5.75000
#
#                                                     50%          75%  \
# fbh_kalte                                      1.130000     2.990000
# Graz Temperature [2 m elevation corrected]    12.771369    19.481371
# Graz Shortwave Radiation                      40.717500   327.520000
# Graz Direct Shortwave Radiation                9.885448   185.670963
# Graz Diffuse Shortwave Radiation              19.613374   146.926073
# Graz Relative Humidity [2 m]                  64.000000    76.000000
# is_schoolday                                   0.000000     1.000000
# day                                           17.000000    24.000000
# month                                          9.000000    11.000000
# year                                        2021.000000  2021.000000
# hour                                          11.500000    17.250000
#
#                                                    max
# fbh_kalte                                      8.72000
# Graz Temperature [2 m elevation corrected]    31.26137
# Graz Shortwave Radiation                     901.57000
# Graz Direct Shortwave Radiation              612.54310
# Graz Diffuse Shortwave Radiation             301.07526
# Graz Relative Humidity [2 m]                  98.00000
# is_schoolday                                   1.00000
# day                                           31.00000
# month                                         12.00000
# year                                        2022.00000
# hour                                          23.00000

# %%
test_df = X_test
test_df['fbh_kalte_pred'] = DTRPred
test_df['fbh_kalte_real'] = y_test

# %%
test_df
# Out:
#        Graz Temperature [2 m elevation corrected]  Graz Shortwave Radiation  \
# 200                                      2.661370                  0.000000
# 1355                                    -1.651130                  0.000000
# 7596                                    -1.388630                  0.000000
# 8810                                    14.801369                238.075000
# 17448                                   20.231370                354.220000
# ...                                           ...                       ...
# 16662                                   18.566371                886.884980
# 764                                      7.921370                  0.000000
# 7668                                    -0.758630                  0.000000
# 17407                                   14.166370                133.055000
# 9147                                     4.933870                 10.012499
#
#        Graz Direct Shortwave Radiation  Graz Diffuse Shortwave Radiation  \
# 200                           0.000000                          0.000000
# 1355                          0.000000                          0.000000
# 7596                          0.000000                          0.000000
# 8810                        134.195622                        103.879378
# 17448                       307.824340                         46.395657
# ...                                ...                               ...
# 16662                       602.563730                        284.321240
# 764                           0.000000                          0.000000
# 7668                          0.000000                          0.000000
# 17407                        55.357630                         77.697369
# 9147                          5.219691                          4.792808
#
#        Graz Relative Humidity [2 m]  is_schoolday  day  month  hour  \
# 200                           57.00             1   16      6     2
# 1355                          88.75             1   28      6     3
# 7596                          48.00             0    1      9     3
# 8810                          38.50             1   13      9    18
# 17448                         51.00             0   12     12    18
# ...                             ...           ...  ...    ...   ...
# 16662                         39.00             0    4     12    13
# 764                           93.00             1   21      6    23
# 7668                          53.00             0    1      9    21
# 17407                         57.50             0   12     12     8
# 9147                          63.50             1   17      9     7
#
#        fbh_kalte_pred  fbh_kalte_real
# 200              0.78            0.77
# 1355             3.68            3.66
# 7596             3.37            3.36
# 8810             1.35            1.62
# 17448            1.11            1.11
# ...               ...             ...
# 16662            1.07            0.01
# 764              0.72            0.74
# 7668             0.85            0.83
# 17407            1.11            1.28
# 9147             2.69            2.19
#
# [3860 rows x 11 columns]
