# %%
#!pip install Jinja2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor


from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv("../data/energy_and_weather.csv",delimiter=',',encoding='UTF-8')

# %%
def timestamp_to_datetime(timestamp):
    date_str = timestamp.split(' ')[0]
    time_str = timestamp.split(' ')[1]
    datetime_obj = datetime.datetime(int(date_str.split('-')[0]), int(date_str.split('-')[1] ), int(date_str.split('-')[2]),int(time_str[:2]), int(time_str[3:4]))
    return datetime_obj

# %%
df['timestamp'] = df['timestamp'].apply(timestamp_to_datetime)

# %%
df['day'] = [x.day for x in df['timestamp']]
df['month'] = [x.month for x in df['timestamp']]
df['year'] = [x.year for x in df['timestamp']]
df['hour'] = [x.hour for x in df['timestamp']]
#minute not imp if we're sampling hourly
#df['minute'] = [x.minute for x in df['timestamp']]

# %% [markdown]
# ### Considering only electricity usage as energy type

# %%
df = df[['timestamp', 'fbh_warme','Graz Temperature [2 m elevation corrected]',
       'Graz Shortwave Radiation', 'Graz Direct Shortwave Radiation',
       'Graz Diffuse Shortwave Radiation', 'Graz Relative Humidity [2 m]',
       'is_schoolday', 'day', 'month', 'year', 'hour']]

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_15754/543879950.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient(cmap='coolwarm')
# <style type="text/css">
# #T_2f766_row0_col0, #T_2f766_row1_col1, #T_2f766_row2_col2, #T_2f766_row3_col3, #T_2f766_row4_col4, #T_2f766_row5_col5, #T_2f766_row6_col6, #T_2f766_row7_col7, #T_2f766_row8_col8, #T_2f766_row9_col9, #T_2f766_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2f766_row0_col1, #T_2f766_row10_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_2f766_row0_col2, #T_2f766_row0_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_2f766_row0_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_2f766_row0_col5 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_2f766_row0_col6, #T_2f766_row7_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_2f766_row0_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_2f766_row0_col8 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_2f766_row0_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_2f766_row0_col10 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_2f766_row1_col0, #T_2f766_row1_col5, #T_2f766_row1_col6, #T_2f766_row1_col8, #T_2f766_row5_col2, #T_2f766_row5_col3, #T_2f766_row5_col4, #T_2f766_row5_col10, #T_2f766_row8_col1, #T_2f766_row8_col7, #T_2f766_row8_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2f766_row1_col2 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_2f766_row1_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_2f766_row1_col4 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_2f766_row1_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_2f766_row1_col9, #T_2f766_row6_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_2f766_row1_col10 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_2f766_row2_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_2f766_row2_col1 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_2f766_row2_col3, #T_2f766_row3_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_2f766_row2_col4, #T_2f766_row4_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_2f766_row2_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_2f766_row2_col6, #T_2f766_row4_col6, #T_2f766_row7_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_2f766_row2_col7, #T_2f766_row3_col7, #T_2f766_row4_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_2f766_row2_col8, #T_2f766_row3_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_2f766_row2_col9, #T_2f766_row3_col9, #T_2f766_row4_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_2f766_row2_col10, #T_2f766_row9_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_2f766_row3_col0, #T_2f766_row6_col10, #T_2f766_row7_col10, #T_2f766_row8_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_2f766_row3_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_2f766_row3_col4, #T_2f766_row4_col3 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_2f766_row3_col5, #T_2f766_row4_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_2f766_row3_col6, #T_2f766_row5_col1, #T_2f766_row5_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_2f766_row3_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_2f766_row4_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_2f766_row4_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_2f766_row4_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_2f766_row4_col10, #T_2f766_row7_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_2f766_row5_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_2f766_row5_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_2f766_row5_col8 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_2f766_row5_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_2f766_row6_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_2f766_row6_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_2f766_row6_col2, #T_2f766_row6_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_2f766_row6_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_2f766_row6_col5, #T_2f766_row10_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_2f766_row6_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_2f766_row6_col8 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_2f766_row7_col0, #T_2f766_row9_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_2f766_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_2f766_row7_col2, #T_2f766_row9_col2, #T_2f766_row10_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_2f766_row7_col3, #T_2f766_row7_col4, #T_2f766_row9_col3, #T_2f766_row9_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_2f766_row7_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_2f766_row8_col0 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_2f766_row8_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_2f766_row8_col3, #T_2f766_row10_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_2f766_row8_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_2f766_row8_col5 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_2f766_row8_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_2f766_row9_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_2f766_row9_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_2f766_row9_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_2f766_row9_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_2f766_row9_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2f766_row10_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_2f766_row10_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_2f766_row10_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_2f766_row10_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_2f766_row10_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_2f766_row10_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f766">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f766_level0_col0" class="col_heading level0 col0" >fbh_warme</th>
#       <th id="T_2f766_level0_col1" class="col_heading level0 col1" >Graz Temperature [2 m elevation corrected]</th>
#       <th id="T_2f766_level0_col2" class="col_heading level0 col2" >Graz Shortwave Radiation</th>
#       <th id="T_2f766_level0_col3" class="col_heading level0 col3" >Graz Direct Shortwave Radiation</th>
#       <th id="T_2f766_level0_col4" class="col_heading level0 col4" >Graz Diffuse Shortwave Radiation</th>
#       <th id="T_2f766_level0_col5" class="col_heading level0 col5" >Graz Relative Humidity [2 m]</th>
#       <th id="T_2f766_level0_col6" class="col_heading level0 col6" >is_schoolday</th>
#       <th id="T_2f766_level0_col7" class="col_heading level0 col7" >day</th>
#       <th id="T_2f766_level0_col8" class="col_heading level0 col8" >month</th>
#       <th id="T_2f766_level0_col9" class="col_heading level0 col9" >year</th>
#       <th id="T_2f766_level0_col10" class="col_heading level0 col10" >hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f766_level0_row0" class="row_heading level0 row0" >fbh_warme</th>
#       <td id="T_2f766_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2f766_row0_col1" class="data row0 col1" >-0.796696</td>
#       <td id="T_2f766_row0_col2" class="data row0 col2" >-0.371897</td>
#       <td id="T_2f766_row0_col3" class="data row0 col3" >-0.356342</td>
#       <td id="T_2f766_row0_col4" class="data row0 col4" >-0.380585</td>
#       <td id="T_2f766_row0_col5" class="data row0 col5" >0.506007</td>
#       <td id="T_2f766_row0_col6" class="data row0 col6" >0.282336</td>
#       <td id="T_2f766_row0_col7" class="data row0 col7" >0.026480</td>
#       <td id="T_2f766_row0_col8" class="data row0 col8" >0.763266</td>
#       <td id="T_2f766_row0_col9" class="data row0 col9" >-0.007359</td>
#       <td id="T_2f766_row0_col10" class="data row0 col10" >-0.095119</td>
#     </tr>
#     <tr>

# %%
X = df[['Graz Temperature [2 m elevation corrected]',
       'Graz Shortwave Radiation', 'Graz Direct Shortwave Radiation',
       'Graz Diffuse Shortwave Radiation', 'Graz Relative Humidity [2 m]',
       'is_schoolday', 'day', 'month', 'hour']]
Y = df['fbh_warme']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Fitting fbh_warme DTR model

# %% [markdown]
# ### Decision Tree Regressor

# %%
DecTreeReg= DecisionTreeRegressor()
DecTreeReg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
DTRPred=DecTreeReg.predict(X_test)

# %% [markdown]
# Evaluation

# %%
mse = (np.sqrt(mean_squared_error(y_test, DTRPred)))
r2= r2_score(y_test, DTRPred)
mae = mean_absolute_error(y_test, DTRPred)
print("Perfomance for test set {:.2f}".format(r2))
# Out:
# Perfomance for test set 0.79

# %%
plt.figure()
plt.figure(figsize=(7, 7))
plt.grid()
plt.scatter(y_test,DTRPred,alpha=0.5
        ,color='green',label=r'$R^2 = $ {:.2f}'.format(r2))
plt.title("Tree Regressor Model")
plt.ylabel("Real values")
plt.xlabel("Predicted values")
plt.legend(prop={'size': 15})
plt.show()

# %%
X_train.describe().T
# Out:
#                                              count        mean         std  \
# Graz Temperature [2 m elevation corrected]  3859.0   14.816830    8.808318
# Graz Shortwave Radiation                    3859.0  177.528822  244.487800
# Graz Direct Shortwave Radiation             3859.0  107.959619  160.191932
# Graz Diffuse Shortwave Radiation            3859.0   69.569202   89.135113
# Graz Relative Humidity [2 m]                3859.0   61.264317   13.763088
# is_schoolday                                3859.0    0.438715    0.496294
# day                                         3859.0   16.334543    8.770017
# month                                       3859.0    9.221819    1.902641
# hour                                        3859.0   11.506867    6.938158
#
#                                                   min       25%        50%  \
# Graz Temperature [2 m elevation corrected]  -3.458630   7.30637  15.401369
# Graz Shortwave Radiation                     0.000000   0.00000  10.680000
# Graz Direct Shortwave Radiation             -8.570068   0.00000   3.112557
# Graz Diffuse Shortwave Radiation             0.000000   0.00000   4.706592
# Graz Relative Humidity [2 m]                29.000000  51.00000  61.000000
# is_schoolday                                 0.000000   0.00000   0.000000
# day                                          1.000000   9.00000  17.000000
# month                                        1.000000   8.00000   9.000000
# hour                                         0.000000   5.00000  12.000000
#
#                                                   75%        max
# Graz Temperature [2 m elevation corrected]   22.10137   32.85137
# Graz Shortwave Radiation                    323.07000  879.32000
# Graz Direct Shortwave Radiation             182.03119  597.19660
# Graz Diffuse Shortwave Radiation            138.82929  295.41666
# Graz Relative Humidity [2 m]                 71.00000   98.00000
# is_schoolday                                  1.00000    1.00000
# day                                          24.00000   31.00000
# month                                        11.00000   12.00000
# hour                                         18.00000   23.00000

# %%
test_df = X_test
test_df['fbh_warme_pred'] = DTRPred
test_df['fbh_warme_real'] = y_test

# %%
test_df
# Out:
#       Graz Temperature [2 m elevation corrected]  Graz Shortwave Radiation  \
# 3221                                    3.811370                   0.00000
# 1117                                   29.321371                 825.92000
# 468                                    25.281370                 856.18000
# 1129                                   23.221370                   0.00000
# 2754                                   14.541369                   1.78000
# ...                                          ...                       ...
# 1056                                   22.281370                   0.00000
# 270                                    19.191370                 173.55000
# 3776                                    4.361370                  43.61000
# 1482                                   31.071371                 235.84999
# 3822                                    7.191370                   0.00000
#
#       Graz Direct Shortwave Radiation  Graz Diffuse Shortwave Radiation  \
# 3221                         0.000000                          0.000000
# 1117                       556.270500                        269.649500
# 468                        583.188960                        272.991030
# 1129                         0.000000                          0.000000
# 2754                         0.056351                          1.723649
# ...                               ...                               ...
# 1056                         0.000000                          0.000000
# 270                         95.741780                         77.808220
# 3776                        22.897547                         20.712454
# 1482                       132.902150                        102.947845
# 3822                         0.000000                          0.000000
#
#       Graz Relative Humidity [2 m]  is_schoolday  day  month  hour  \
# 3221                          63.0             0   26     10     6
# 1117                          42.0             0   30      7    14
# 468                           30.0             0    3      7    13
# 1129                          61.0             0   31      7     2
# 2754                          68.0             1    6     10    19
# ...                            ...           ...  ...    ...   ...
# 1056                          58.0             0   28      7     1
# 270                           59.0             1   25      6     7
# 3776                          69.0             1   18     11     9
# 1482                          43.0             0   14      8    19
# 3822                          69.0             0   20     11     7
#
#       fbh_warme_pred  fbh_warme_real
# 3221             7.0             7.0
# 1117             0.0             0.0
# 468              0.0             0.0
# 1129             0.0             0.0
# 2754             7.0             4.0
# ...              ...             ...
# 1056             0.0             0.0
# 270              0.0             0.0
# 3776             6.0             8.0
# 1482             0.0             0.0
# 3822             7.0             7.0
#
# [965 rows x 11 columns]
